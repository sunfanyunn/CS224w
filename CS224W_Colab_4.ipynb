# %% [markdown]
# <a href="https://colab.research.google.com/github/fanyun-sun/CS224w/blob/main/CS224W_Colab_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CS224W - Colab 4**

# %% [markdown]
# In this Colab, we will shift our focus from homogenous graphs to heterogeneous graphs. Heterogeneous graphs extend the traditional homogenous graphs that we have seen before by specifically incorperating different node and edge types. This additional information allows us to extend the graph neural nework models that we have worked with before. Namely, we can apply heterogenous message passing, where different message types now exist between different node, edge type relationships.
#
# At first, we will learn how to transform NetworkX graphs into DeepSNAP representations. Additionally, we will dive deeper into how DeepSNAP stores and represents heterogeneous graphs as PyTorch Tensors.
#
# Then, we will build our own heterogenous graph neural netowrk models using PyTorch Geonetric and DeepSNAP on node property prediction task. To evaluate these models, we will use our model on the heterogeneous ACM dataset.
#
# **Note**: Make sure to **sequentially run all the cells in each section**, so that the intermediate variables / packages will carry over to the next cell
#
# Have fun on Colab 4 :)

# %% [markdown]
# # Device
# You might need to use GPU for this Colab.
#
# Please click `Runtime` and then `Change runtime type`. Then set the `hardware accelerator` to **GPU**.

# %% [markdown]
# # Installation

# %%
#!pip install -q torch-scatter -f https://pytorch-geometric.com/whl/torch-1.7.0+cu101.html
#!pip install -q torch-sparse -f https://pytorch-geometric.com/whl/torch-1.7.0+cu101.html
# !pip install -q torch-scatter -f https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# !pip install -q torch-sparse -f https://pytorch-geometric.com/whl/torch-1.8.0+cu101.html
# !pip install -q torch-geometric
# !pip install -q git+https://github.com/snap-stanford/deepsnap.git
# !pip install -U -q PyDrive
# Out:
#   Building wheel for deepsnap (setup.py) ... done
#   Building wheel for deepsnap (setup.py) ... done

# %%
import torch_geometric
torch_geometric.__version__
# Out:
# '1.6.3'
# '1.6.3'

# %% [markdown]
# # 1 DeepSNAP Heterogeneous Graph
#
# First, we will explore how to transform NetworkX graphs into the format supported by DeepSNAP.
#
# In order to extend the traditional DeepSNAP representation of graphs to include heterogenous graphs, we include the following graph property features:
# * `node_feature`: The feature of each node (`torch.tensor`)
# * `edge_feature`: The feautre of each edge (`torch.tensor`)
# * `node_label`: The label of each node (`int`)
# * `node_type`: The node type of each node (`string`)
# * `edge_type`: The edge type of each edge (`string`)
#
# The key new features we add are `node_type` and `edge_type`, which enables us to perform heterogenous message passing.
#
# In this first question we will work with the familiar [karate club graph](https://networkx.github.io/documentation/stable/auto_examples/graph/plot_karate_club.html) seen in assignment one. To start, since each node in the graph belongs to one of two clubs (club "Mr. Hi" or club "Officer"), we will treat the club as the `node_type`. The code below demonstrates how to differentiate the nodes in the NetworkX graph.

# %%
from pylab import *
import networkx as nx
from networkx.algorithms.community import greedy_modularity_communities
import matplotlib.pyplot as plt
import copy

G = nx.karate_club_graph()
community_map = {}
for node in G.nodes(data=True):
  if node[1]["club"] == "Mr. Hi":
    community_map[node[0]] = 0
  else:
    community_map[node[0]] = 1
node_color = []
color_map = {0: 0, 1: 1}
node_color = [color_map[community_map[node]] for node in G.nodes()]
pos = nx.spring_layout(G)
plt.figure(figsize=(7, 7))
nx.draw(G, pos=pos, cmap=plt.get_cmap('coolwarm'), node_color=node_color)
show()

# %% [markdown]
# ### Question 1.1: Assigning Node Type and Node Features (Not Specifically Graded)
#
# Using the `community_map` dictionary and graph `G` from above, add node attributes `node_type` and `node_label` to the graph G. Namely, for `node_type` assign nodes in the "Mr. Hi" club to a node type `n0` and nodes in club "Officer" a node type `n1`.
#
# Then for `node_label`, assign nodes in "Mr. Hi" club to a `node_label` `0` and nodes in club "Officer" a `node_label` of `1`.
#
# Lastly, assign every node a feature vector [1, 1, 1, 1, 1].
#
# **Hint**: Look at the NetworkX function `nx.classes.function.set_node_attributes`.
#
# **Note**: This question is not specifically graded but is important for later questions.

# %%
import torch

def assign_node_types(G, community_map):
  # TODO: Implement this function that takes in a NetworkX graph
  # G and community map assignment (mapping node ids --> 0/1 labels)
  # and adds 'node_type' as a node_attribute in G.

  ############# Your code here ############
  ## (~2 line of code)
  ## Note
  ## 1. Look up NetworkX `nx.classes.function.set_node_attributes`
  map = {k:'n1' if v else 'n0' for k,v in community_map.items()}
  nx.classes.function.set_node_attributes(G, map, name='node_type')


  #########################################

def assign_node_labels(G, community_map):
  # TODO: Implement this function that takes in a NetworkX graph
  # G and community map assignment (mapping node ids --> 0/1 labels)
  # and adds 'node_label' as a node_attribute in G.

  ############# Your code here ############
  ## (~2 line of code)
  ## Note
  ## 1. Look up NetworkX `nx.classes.function.set_node_attributes`
  nx.classes.function.set_node_attributes(G, community_map, name='node_label')

  #########################################

def assign_node_features(G):
  # TODO: Implement this function that takes in a NetworkX graph
  # G and adds 'node_feature' as a node_attribute in G. Each node
  # in the graph has the same feature vector [1., 1., 1., 1., 1.]

  ############# Your code here ############
  ## (~2 line of code)
  ## Note
  ## 1. Look up NetworkX `nx.classes.function.set_node_attributes`
  map = {n : [1., 1., 1., 1., 1.] for n in G.nodes()}
  nx.classes.function.set_node_attributes(G, map, name='node_label')

  #########################################

assign_node_types(G, community_map)
assign_node_types(G, community_map)
assign_node_labels(G, community_map)

# %% [markdown]
# ### Question 1.2: Assigning Edge Types (Not Specifically Graded)
#
# Next, we will assign three different types of `edge_type` to the edges:
# * Edges within club "Mr. Hi": `e0`
# * Edges within club "Officer": `e1`
# * Edges between clubs: `e2`
#
# **Hint**: Use the `community_map` from before and `nx.classes.function.set_edge_attributes`

# %%
def assign_edge_types(G, community_map):
  # TODO: Implement this function that takes in a NetworkX graph
  # G and community map assignment (mapping node ids --> 0/1 labels)
  # and adds 'edge_type' as a edge_attribute in G.

  ############# Your code here ############
  ## (~5 line of code)
  ## Note
  ## 1. Create an edge assignment dict following rules above
  edge_map = {}
  for e in G.edges():
    if G.nodes[e[0]]['club'] == 'Mr. Hi' and G.nodes[e[1]]['club'] == 'Mr. Hi':
      edge_map[e] = 'e0'
    elif G.nodes[e[0]]['club'] == 'Officer' and G.nodes[e[1]]['club'] == 'Officer':
      edge_map[e] = 'e1'
    else:
      edge_map[e] = 'e2'
  nx.classes.function.set_edge_attributes(G, edge_map, name='edge_type')

  #########################################

assign_edge_types(G, community_map)

# %% [markdown]
# ## Heterogeneous Graph Visualization
#
# Now we can visualize the Heterogeneous Graph we have generated.

# %%
edge_color = {}
for edge in G.edges():
  n1, n2 = edge
  edge_color[edge] = community_map[n1] if community_map[n1] == community_map[n2] else 2
  if community_map[n1] == community_map[n2] and community_map[n1] == 0:
    edge_color[edge] = 'blue'
  elif community_map[n1] == community_map[n2] and community_map[n1] == 1:
    edge_color[edge] = 'red'
  else:
    edge_color[edge] = 'green'

G_orig = copy.deepcopy(G)
nx.classes.function.set_edge_attributes(G, edge_color, name='color')
colors = nx.get_edge_attributes(G,'color').values()
labels = nx.get_node_attributes(G, 'node_type')
plt.figure(figsize=(8, 8))
nx.draw(G, pos=pos, cmap=plt.get_cmap('coolwarm'), node_color=node_color, edge_color=colors, labels=labels, font_color='white')
show()

# %% [markdown]
# which include edges within each clubs (2 types) and edges across two clubs (1 type). Different types of nodes and edges are visualized in different colors. The NetworkX object `G` in following code can be transformed into `deepsnap.hetero_graph.HeteroGraph` directly.

# %% [markdown]
# ## Transforming to DeepSNAP representation
#
# The NetworkX object `G` in following code can be transformed into `deepsnap.hetero_graph.HeteroGraph` directly!

# %%
from deepsnap.hetero_graph import HeteroGraph

hete = HeteroGraph(G_orig)

# %% [markdown]
# ## Question 1.3: How many nodes are of each type (10 Points)
#
# Submit your answers on Gradescope.

# %%
def get_nodes_per_type(hete):
  # TODO: Implement this function that takes a DeepSNAP dataset object
  # and return the number of nodes per `node_type`.

  num_nodes_n0 = 0
  num_nodes_n1 = 0

  ############# Your code here ############
  ## (~2 line of code)
  ## Note
  ## 1. Colab autocomplete functionality might be useful.
  num_nodes_n0 =  hete.num_nodes('n0')
  num_nodes_n1 =  hete.num_nodes('n1')


  #########################################

  return num_nodes_n0, num_nodes_n1

num_nodes_n0, num_nodes_n1 = get_nodes_per_type(hete)
print("Node type n0 has {} nodes".format(num_nodes_n0))
print("Node type n1 has {} nodes".format(num_nodes_n1))
# Out:
# Node type n0 has 17 nodes
# Node type n1 has 17 nodes
# Node type n0 has 17 nodes
# Node type n1 has 17 nodes

# %% [markdown]
# ## Question 1.4: Message Types: How many edges are of each message type (10 Points)
#
# Submit your answers on Gradescope.
#
# When working with heterogenous graphs, as we have discussed before, we now work with heterogenous message types (i.e. different message types for `node_type` and `edge_type` combinations). For example, an edge of type `e0` connecting two nodes in club "Mr. HI" would have a message type of (`n0`, `e0`, `n0`). In this problem we will analyze how many edges in our graph are of each message type.
#
# **Hint**: If you want to learn more about what the different message types are try the call `hete.message_types`

# %%
def get_num_message_edges(hete):
  # TODO: Implement this function that takes a DeepSNAP dataset object
  # and return the number of edges for each message type. 
  # You should return a list of tuples as 
  # (message_type, num_edge)

  message_type_edges = []

  ############# Your code here ############
  ## (~2 line of code)
  ## Note
  ## 1. Colab autocomplete functionality might be useful.
  for message_type in hete.message_types:
    print(message_type)
    message_type_edges.append((message_type, hete.num_edges(message_type)))


  #########################################

  return message_type_edges

message_type_edges = get_num_message_edges(hete)
for (message_type, num_edges) in message_type_edges:
  print("Message type {} has {} edges".format(message_type, num_edges))
# Out:
# ('n0', 'e0', 'n0')
# ('n0', 'e2', 'n1')
# ('n1', 'e1', 'n1')
# Message type ('n0', 'e0', 'n0') has 35 edges
# Message type ('n0', 'e2', 'n1') has 11 edges
# Message type ('n1', 'e1', 'n1') has 32 edges
# ('n0', 'e0', 'n0')
# ('n0', 'e2', 'n1')
# ('n1', 'e1', 'n1')
# Message type ('n0', 'e0', 'n0') has 35 edges
# Message type ('n0', 'e2', 'n1') has 11 edges
# Message type ('n1', 'e1', 'n1') has 32 edges

# %% [markdown]
# ## Question 1.5: Dataset Splitting: How many nodes in each dataset split? (10 Points)
#
# Submit your answers on Gradescope.
#
# DeepSNAP has built in Dataset creation and splitting methods for heterogeneous graphs. Here we will create train, validation, and test datasets for a node prediction task and inspect the resulting subgraphs. Specifically, write a function that computes the number of nodes in each dataset split.

# %%
from deepsnap.dataset import GraphDataset

def compute_dataset_split_counts(datasets):
  # TODO: Implement this function that takes a dict of datasets
  # and returns a dict mapping dataset names to the number of labeled
  # nodes used for supervision in that respective dataset.  
  
  data_set_splits = {}

  ############# Your code here ############
  ## (~3 line of code)
  ## Note
  ## 1. DeepSNAP `node_label_index` will be helpful.
  ## 2. Remember to count both node_types
  for dataset_name, dataset in datasets.items():
    data_set_splits[dataset_name] = 0
    print(dataset[0].node_label_index)
    for k, v in dataset[0].node_label_index.items():
      data_set_splits[dataset_name] += v.shape[0]

  #########################################

  return data_set_splits


dataset = GraphDataset([hete], task='node')
# Splitting the dataset
dataset_train, dataset_val, dataset_test = dataset.split(transductive=True, split_ratio=[0.4, 0.3, 0.3])
datasets = {'train': dataset_train, 'val': dataset_val, 'test': dataset_test}

data_set_splits = compute_dataset_split_counts(datasets)
for dataset_name, num_nodes in data_set_splits.items():
  print("{} dataset has {} nodes".format(dataset_name, num_nodes))
# Out:
# {'n0': tensor([ 8, 14,  9,  5, 13, 16]), 'n1': tensor([16, 13, 14,  1,  5,  2])}
# {'n0': tensor([ 4, 10,  2, 11,  3]), 'n1': tensor([ 7,  6,  0, 10, 11])}
# {'n0': tensor([ 7,  1, 15,  0,  6, 12]), 'n1': tensor([ 3, 15,  9,  8,  4, 12])}
# train dataset has 12 nodes
# val dataset has 10 nodes
# test dataset has 12 nodes
# {'n0': tensor([ 5,  8,  6,  1, 10, 14]), 'n1': tensor([ 0, 10,  9, 14, 12, 15])}
# {'n0': tensor([ 7, 16,  9,  4, 13]), 'n1': tensor([ 6,  5, 11,  3, 13])}
# {'n0': tensor([ 3, 12, 15,  2,  0, 11]), 'n1': tensor([ 1,  7,  2,  8,  4, 16])}
# train dataset has 12 nodes
# val dataset has 10 nodes
# test dataset has 12 nodes

# %% [markdown]
# ## DeepSNAP Dataset Visualization

# %%
from deepsnap.dataset import GraphDataset

dataset = GraphDataset([hete], task='node')
# Splitting the dataset
dataset_train, dataset_val, dataset_test = dataset.split(transductive=True, split_ratio=[0.4, 0.3, 0.3])
titles = ['Train', 'Validation', 'Test']

for i, dataset in enumerate([dataset_train, dataset_val, dataset_test]):
  n0 = hete._convert_to_graph_index(dataset[0].node_label_index['n0'], 'n0').tolist()
  n1 = hete._convert_to_graph_index(dataset[0].node_label_index['n1'], 'n1').tolist()

  plt.figure(figsize=(7, 7))
  plt.title(titles[i])
  nx.draw(G_orig, pos=pos, node_color="grey", edge_color=colors, labels=labels, font_color='white')
  nx.draw_networkx_nodes(G_orig.subgraph(n0), pos=pos, node_color="blue")
  nx.draw_networkx_nodes(G_orig.subgraph(n1), pos=pos, node_color="red")
  show()

# %% [markdown]
# # 2 Heterogeneous Graph Node Property Prediction
#
# In this part we will use PyTorch Geometric and DeepSNAP to implement a GNN model for heterogeneous graph node property prediction (node classification). This part of Colab requires you having good understandings on the heterogeneous graph and how to implement the GNN layers by using PyG.
#
# At first let's take look at the general structure of a heterogeneous layer by an example.
#
# Let's assume we have a graph $G$, which contains two node types $a$ and $b$, and three message types $m_1=(a, r_1, a)$, $m_2=(a, r_2, b)$ and $m_3=(a, r_3, b)$.
#
# Thus, for $G$ a heterogeneous layer will contains three Heterogeneous GNN layers (`HeteroGNNConv` in this Colab) where each `HeteroGNNConv` layer will perform the message passing and aggregation with respect to only one message type. The overview of the heterogeneous layer is shown below:
#
# <br/>
# <center>
# <img src="https://web.stanford.edu/class/cs224w/images/colab4/hetero_conv.png"/>
# </center>
# <br/>
#
# In this Colab, all the $l^{th}$ Heterogeneous GNN layers will be managed by a ($l^{th}$) Heterogeneous GNN Wrapper layer (the `HeteroGNNWrapperConv`). The $l^{th}$ Heterogeneous GNN Wrapper layer will take in the input node embeddings from $(l-1)^{th}$ layer and aggregate (across message types) the Heterogeneous GNN layers' results. For example, the wrapper layer will aggregate node type $b$'s node embeddings from Heterogeneous GNN layers for $m_2$ and $m_3$. The "simplified" heterogeneous layer structure is shown below:
#
# <br/>
# <center>
# <img src="http://web.stanford.edu/class/cs224w/images/colab4/hetero_conv_1.png"/>
# </center>
# <br/>

# %% [markdown]
# <font color='red'>We recommend you implement the heterogeneous GNN model in following steps:</font>
#
# 1. Implement the `HeteroGNNConv` first.
# 2. Implement the `mean` aggregation in `HeteroGNNWrapperConv`.
# 3. Implement the `generate_convs`.
# 4. Implement the `HeteroGNN` model and the `train` function.
# 5. Train the model with `mean` aggregation across the message types and make sure your model has reasonable performance.
# 6. Implement the `attn` aggregation in `HeteroGNNWrapperConv`.
# 7. Train the model with `attn` aggregation across the message types and make sure your model has reasonable performance.

# %% [markdown]
# ## Setup

# %%
import copy
import torch
import deepsnap
import numpy as np
import torch.nn as nn
import torch.nn.functional as F
import torch_geometric.nn as pyg_nn

from sklearn.metrics import f1_score
from deepsnap.hetero_gnn import forward_op
from deepsnap.hetero_graph import HeteroGraph
from torch_sparse import SparseTensor, matmul

# %% [markdown]
# ## Dataset
#
# You need to login to your Google account and enter the verification code below.

# %%
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# Authenticate and create the PyDrive client
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# %%
id='1ivlxd6lJMcZ9taS44TMGG72x2V1GeVvk'
downloaded = drive.CreateFile({'id': id})
downloaded.GetContentFile('acm.pkl')

# %% [markdown]
# ## Heterogeneous GNN Layer
#
# Now let's start working on our own implementation of a heterogeneous layer (the `HeteroGNNConv`)! Similar to what we did in Colab 3, we will implement the layer using PyTorch Geometric. In general, our heterogeneous GNN layer draws ideas from the **GraphSAGE** ([Hamilton et al. (2017)](https://arxiv.org/abs/1706.02216)).
#
# At first, let's implement the GNN layer for each message type :
#
# \begin{equation}
# m =(s, r, d)
# \end{equation}
#
# Each message type is a tuple containing three elements where $s$ refers to the source node type, $r$ refers to the edge (relation) type and $d$ refers to the destination node type. The update rule is very similar to that of GraphSAGE but we need to include the node types and the edge type. The update rule is described as below:
#
# \begin{equation}
# h_v^{(l)[m]} = W^{(l)[m]} \cdot \text{CONCAT} \Big( W_d^{(l)[m]} \cdot h_v^{(l-1)}, W_s^{(l)[m]} \cdot AGG(\{h_u^{(l-1)}, \forall u \in N_{m}(v) \})\Big)
# \end{equation}
#
# where $[m]$ indicates that the weight matrices or embeddings with respect to message type $m$, $W_s^{(l)[m]}$ computes the messages from neighboring nodes, $W_d^{(l)[m]}$ compute messages from the node itself, and $W^{(l)[m]}$ aggregates messages from both node types. In the equation above, $v$ has the node type $d$, and $u$ has the node type $s$.
#
# For simplicity, we use mean aggregations for $AGG$ where:
#
# \begin{equation}
# AGG(\{h_u^{(l-1)}, \forall u \in N_{m}(v) \}) = \frac{1}{|N_{m}(v)|} \sum_{u\in N_{m}(v)} h_u^{(l-1)}
# \end{equation}

# %%
class HeteroGNNConv(pyg_nn.MessagePassing):
    def __init__(self, in_channels_src, in_channels_dst, out_channels):
        super(HeteroGNNConv, self).__init__(aggr="mean")

        self.in_channels_src = in_channels_src
        self.in_channels_dst = in_channels_dst
        self.out_channels = out_channels

        # To simplify implementation, please initialize both self.lin_dst
        # and self.lin_src out_features to out_channels
        self.lin_dst = None
        self.lin_src = None

        self.lin_update = None

        ############# Your code here #############
        ## (~3 lines of code)
        self.lin_dst = nn.Linear(self.in_channels_src, self.out_channels)
        self.lin_src = nn.Linear(self.in_channels_src, self.out_channels)
        self.lin_update = nn.Linear(self.out_channels*2, self.out_channels)


        ##########################################

    def forward(
        self,
        node_feature_src,
        node_feature_dst,
        edge_index,
        size=None,
        res_n_id=None,
    ):
        ############# Your code here #############
        ## (~1 line of code)
        return self.propagate(edge_index, size=size,
                              node_feature_src=node_feature_src,
                              node_feature_dst=node_feature_dst,
                              res_n_id=res_n_id)


        ##########################################

    def message_and_aggregate(self, edge_index, node_feature_src):

        ############# Your code here #############
        ## (~1 line of code)
        ## Note:
        ## 1. Different from what we implemented in Colab 3, we use message_and_aggregate
        ## to replace the message and aggregate. The benefit is that we can avoid
        ## materializing x_i and x_j, and make the implementation more efficient.
        ## 2. To implement efficiently, following PyG documentation is helpful:
        ## https://pytorch-geometric.readthedocs.io/en/latest/notes/sparse_tensor.html
        ## 3. Here edge_index is torch_sparse SparseTensor.

        #out = torch_scatter.scatter(node_feature_src, edge_index, reduce='mean')
        adj_t = edge_index
        x = node_feature_src
        return matmul(adj_t, x, reduce=self.aggr)


        ##########################################

        return out

    def update(self, aggr_out, node_feature_dst, res_n_id):

        ############# Your code here #############
        ## (~4 lines of code)
        aggr_out = self.lin_src(aggr_out)
        node_feature_dst = self.lin_dst(node_feature_dst)
        
        aggr_out = torch.cat([aggr_out, node_feature_dst], dim=-1)
        aggr_out = self.lin_update(aggr_out)
        ##########################################

        return aggr_out

# %% [markdown]
# ## Heterogeneous GNN Wrapper Layer
#
# After implementing the GNN layer for each message type, we need to somehow aggregate the the node embedding results (with respect to each message types) together. Here we will implement two types of message type level aggregation.
#
# The first one is simply the mean aggregation:
#
# \begin{equation}
# h_v^{(l)} = \frac{1}{M}\sum_{m=1}^{M}h_v^{(l)[m]}
# \end{equation}
#
# Here node $v$ has the node type $d$ and $M$ is the total number of message types that the destination node type is $d$.
#
# The other one is the semantic level attention introduced in **HAN** ([Wang et al. (2019)](https://arxiv.org/abs/1903.07293)). Instead of directly averaging on the message type aggregation results, we use attention to learn which message type result can be more important, then aggregate from all the message types. Following are the equations for semantic level attention:
#
# \begin{equation}
# e_{m} = \frac{1}{|V_{d}|} \sum_{v \in V_{d}} q_{attn}^T \cdot tanh \Big( W_{attn}^{(l)} \cdot h_v^{(l)[m]} + b \Big)
# \end{equation}
#
# where $m$ refers to message type and $d$ refers to the destination node type. Then we can compute the attention and update the $h_v^{(l)}$:
#
# \begin{equation}
# \alpha_{m} = \frac{\exp(e_{m})}{\sum_{m=1}^M \exp(e_{m})}
# \end{equation}
#
# \begin{equation}
# h_v^{(l)} = \sum_{m=1}^{M} \alpha_{m} \cdot h_v^{(l)[m]}
# \end{equation}

# %%
class HeteroGNNWrapperConv(deepsnap.hetero_gnn.HeteroConv):
    def __init__(self, convs, args, aggr="mean"):
        super(HeteroGNNWrapperConv, self).__init__(convs, None)
        self.aggr = aggr

        # Map the index and message type
        self.mapping = {}

        # A numpy array that stores the final attention probability
        self.alpha = None

        self.attn_proj = None

        if self.aggr == "attn":
            ############# Your code here #############
            ## (~1 line of code)
            ## Note:
            ## 1. Initialize self.attn_proj here.
            ## 2. You should use nn.Sequential for self.attn_proj
            ## 3. nn.Linear and nn.Tanh are useful.
            ## 4. You can create a vector parameter by using:
            ## nn.Linear(some_size, 1, bias=False)
            ## 5. The first linear layer should have out_features as args['attn_size']
            ## 6. You can assume we only have one "head" for the attention.
            ## 7. We recommend you to implement the mean aggregation first. After 
            ## the mean aggregation works well in the training, then you can 
            ## implement this part.

            self.attn_proj = nn.Sequential(
                nn.Linear(args['hidden_size'], args['attn_size'], bias=True),
                nn.Tanh(),
                nn.Linear(args['attn_size'], 1)
            )

            ##########################################
    
    def reset_parameters(self):
        super(HeteroConvWrapper, self).reset_parameters()
        if self.aggr == "attn":
            for layer in self.attn_proj.children():
                layer.reset_parameters()
    
    def forward(self, node_features, edge_indices):
        message_type_emb = {}
        for message_key, message_type in edge_indices.items():
            src_type, edge_type, dst_type = message_key
            node_feature_src = node_features[src_type]
            node_feature_dst = node_features[dst_type]
            edge_index = edge_indices[message_key]
            message_type_emb[message_key] = (
                self.convs[message_key](
                    node_feature_src,
                    node_feature_dst,
                    edge_index,
                )
            )
        node_emb = {dst: [] for _, _, dst in message_type_emb.keys()}
        mapping = {}        
        for (src, edge_type, dst), item in message_type_emb.items():
            mapping[len(node_emb[dst])] = (src, edge_type, dst)
            node_emb[dst].append(item)
        self.mapping = mapping
        for node_type, embs in node_emb.items():
            if len(embs) == 1:
                node_emb[node_type] = embs[0]
            else:
                node_emb[node_type] = self.aggregate(embs)
        return node_emb
    
    def aggregate(self, xs):
        # TODO: Implement this function that aggregates all message type results.
        # Here, xs is a list of tensors (embeddings) with respect to message 
        # type aggregation results.

        if self.aggr == "mean":

            ############# Your code here #############
            ## (~2 lines of code)
            x = torch.stack(xs, dim=-1)
            return x.mean(dim=-1)


            ##########################################

        elif self.aggr == "attn":

            ############# Your code here #############
            ## (~10 lines of code)
            ## Note:
            ## 1. Store the value of attention alpha (as a numpy array) to self.alpha,
            ## which has the shape (len(xs), ) self.alpha will be not be used 
            ## to backpropagate etc. in the model. We will use it to see how much 
            ## attention the layer pays on different message types.
            ## 2. torch.softmax and torch.cat are useful.
            ## 3. You might need to reshape the tensors by using the 
            ## `view()` function https://pytorch.org/docs/stable/tensor_view.html

            # xs[0].shape [N, hidden_size]
            x = torch.stack(xs, dim=0)
            # x.shape [# msg type, N, hidden_size]
            self.alpha = []

            ret = self.attn_proj(x)
            assert ret.shape[-1] == 1
            ret = ret.view((ret.shape[0], ret.shape[1]))
            # ret.shape [# msg type, N]
            ret = torch.mean(ret, dim=-1)
            print(ret.shape)
            alpha = torch.softmax(ret, dim=0)
            print(alpha)
            # [# msg type, 1]
            self.alpha = alpha.detach().cpu().numpy()


            return (x * alpha[..., None, None].detach()).sum(dim=0)
            # return shape: [N, hidden_size]
            ##########################################

# %% [markdown]
# ## Initialize Heterogeneous GNN Layers
#
# Now let's initialize the Heterogeneous GNN Layers. Different from homogeneous graph case, heterogeneous case can be a little bit complex.
#
# In general, we need to create a dictionary of `HeteroGNNConv` layers where the keys are message types.
#
# * To get all message types, `deepsnap.hetero_graph.HeteroGraph.message_types` is useful.
# * If we are initializing the first conv layers, we need to get the feature dimension of each node type. Using `deepsnap.hetero_graph.HeteroGraph.num_node_features(node_type)` will return the node feature dimension of `node_type`. In this function, we will set each `HeteroGNNConv` `out_channels` to be `hidden_size`.
# * If we are not initializing the first conv layers, all node types will have the same embedding dimension `hidden_size` and we still set `HeteroGNNConv` `out_channels` to be `hidden_size` for simplicity.

# %%
def generate_convs(hetero_graph, conv, hidden_size, first_layer=False):
    # TODO: Implement this function that returns a dictionary of `HeteroGNNConv` 
    # layers where the keys are message types. `hetero_graph` is deepsnap `HeteroGraph`
    # object and the `conv` is the `HeteroGNNConv`.

    convs = {}

    ############# Your code here #############
    ## (~9 lines of code)
    if first_layer:
      for message_type in hetero_graph.message_types:
        node_type_0 = message_type[0]
        node_type_2 = message_type[2]
        feat_dim_0 = hetero_graph.num_node_features(node_type_0)
        feat_dim_2 = hetero_graph.num_node_features(node_type_2)
        print(node_type_0, node_type_2, feat_dim_0, feat_dim_2)
        convs[message_type] = conv(feat_dim_0, feat_dim_2, hidden_size)
    else:
      for message_type in hetero_graph.message_types:
        convs[message_type] = conv(hidden_size, hidden_size, hidden_size)
    ##########################################
    
      print(convs)
    return convs

# %% [markdown]
# ## HeteroGNN
#
# Now we will make a simple HeteroGNN model which contains only two `HeteroGNNWrapperConv` layers.
#
# For the forward function in `HeteroGNN`, the model is going to be run as following:
#
# $\text{self.convs1} \rightarrow \text{self.bns1} \rightarrow \text{self.relus1} \rightarrow \text{self.convs2} \rightarrow \text{self.bns2} \rightarrow \text{self.relus2} \rightarrow \text{self.post_mps}$

# %%
class HeteroGNN(torch.nn.Module):
    def __init__(self, hetero_graph, args, aggr="mean"):
        super(HeteroGNN, self).__init__()

        self.aggr = aggr
        self.hidden_size = args['hidden_size']

        self.convs1 = None
        self.convs2 = None

        self.bns1 = nn.ModuleDict()
        self.bns2 = nn.ModuleDict()
        self.relus1 = nn.ModuleDict()
        self.relus2 = nn.ModuleDict()
        self.post_mps = nn.ModuleDict()

        ############# Your code here #############
        ## (~10 lines of code)
        ## Note:
        ## 1. For self.convs1 and self.convs2, call generate_convs at first and then
        ## pass the returned dictionary of `HeteroGNNConv` to `HeteroGNNWrapperConv`.
        ## 2. For self.bns, self.relus and self.post_mps, the keys are node_types.
        ## `deepsnap.hetero_graph.HeteroGraph.node_types` will be helpful.
        ## 3. Initialize all batchnorms to torch.nn.BatchNorm1d(hidden_size, eps=1.0).
        ## 4. Initialize all relus to nn.LeakyReLU().
        ## 5. For self.post_mps, each value in the ModuleDict is a linear layer 
         ## where the `out_features` is the number of classes for that node type.

          ## `deepsnap.hetero_graph.HeteroGraph.num_node_labels(node_type)` will be
        ## useful.
        self.convs1 = HeteroGNNWrapperConv(generate_convs(hetero_graph, HeteroGNNConv, self.hidden_size, first_layer=True), args, aggr)
        self.convs2 = HeteroGNNWrapperConv(generate_convs(hetero_graph, HeteroGNNConv, self.hidden_size, first_layer=False), args, aggr)
        for node_type in hetero_graph.node_types:
          self.bns1[node_type] = torch.nn.BatchNorm1d(self.hidden_size, eps=1.)
          self.bns2[node_type] = torch.nn.BatchNorm1d(self.hidden_size, eps=1.)
          self.relus1[node_type] = torch.nn.LeakyReLU()
          self.relus2[node_type] = torch.nn.LeakyReLU()
          feat_dim =  hetero_graph.num_node_labels(node_type)
          self.post_mps[node_type] = nn.Linear(self.hidden_size, feat_dim)
        ##########################################

    def forward(self, node_feature, edge_index):
        # TODO: Implement the forward function. Notice that `node_feature` is 
        # a dictionary of tensors where keys are node types and values are 
        # corresponding feature tensors. The `edge_index` is a dictionary of 
        # tensors where keys are message types and values are corresponding
        # edge index tensors (with respect to each message type).

        x = node_feature

        ############# Your code here #############
        ## (~7 lines of code)
        ## Note:
        ## 1. `deepsnap.hetero_gnn.forward_op` can be helpful.
        x = self.convs1(x, edge_index)
        x = forward_op(x, self.bns1)
        x = forward_op(x, self.relus1)
        x = self.convs2(x, edge_index)
        x = forward_op(x, self.bns2)
        x = forward_op(x, self.relus2)
        x = forward_op(x, self.post_mps)


        ##########################################
        
        return x

    def loss(self, preds, y, indices):
        
        loss = 0
        loss_func = F.cross_entropy

        ############# Your code here #############
        ## (~3 lines of code)
        ## Note:
        ## 1. For each node type in preds, accumulate computed loss to `loss`
        ## 2. Loss need to be computed with respect to the given index
        print(preds['paper'].shape, indices['paper'].shape, y['paper'].shape)
        for key in preds.keys():
          indice = indices[key]
          loss += loss_func(preds[key][indice], y[key][indice])
        ##########################################

        return loss

# %% [markdown]
# ## Training and Testing
#
# Here we provide you with the functions to train and test. You only need to implement one line of code here.
#
# **Please do not modify other parts in `train` and `test` for grading purposes.**

# %%
def train(model, optimizer, hetero_graph, train_idx):
    model.train()
    optimizer.zero_grad()
    preds = model(hetero_graph.node_feature, hetero_graph.edge_index)

    loss = None

    ############# Your code here #############
    ## Note:
    ## 1. `deepsnap.hetero_graph.HeteroGraph.node_label` is useful
    ## 2. Compute the loss here
    loss = model.loss(preds, hetero_graph.node_label, train_idx)
    ##########################################

    loss.backward()
    optimizer.step()
    return loss.item()

def test(model, graph, indices, best_model=None, best_val=0):
    model.eval()
    accs = []
    for index in indices:
        preds = model(graph.node_feature, graph.edge_index)
        num_node_types = 0
        micro = 0
        macro = 0
        for node_type in preds:
            idx = index[node_type]
            pred = preds[node_type][idx]
            pred = pred.max(1)[1]
            label_np = graph.node_label[node_type][idx].cpu().numpy()
            pred_np = pred.cpu().numpy()
            micro = f1_score(label_np, pred_np, average='micro')
            macro = f1_score(label_np, pred_np, average='macro')
            num_node_types += 1
        # Averaging f1 score might not make sense, but in our example we only
        # have one node type
        micro /= num_node_types
        macro /= num_node_types
        accs.append((micro, macro))
    if accs[1][0] > best_val:
        best_val = accs[1][0]
        best_model = copy.deepcopy(model)
    return accs, best_model, best_val

# %%
# Please do not change the following parameters
args = {
    'device': torch.device('cuda' if torch.cuda.is_available() else 'cpu'),
    'hidden_size': 64,
    'epochs': 100,
    'weight_decay': 1e-5,
    'lr': 0.003,
    'attn_size': 32,
}

# %% [markdown]
# ## Dataset and Preprocessing
#
# In the next, we will load the data and create a tensor backend (without a NetworkX graph) `deepsnap.hetero_graph.HeteroGraph` object.
#
# We will use the `ACM(3025)` dataset in our node property prediction task, which is proposed in **HAN** ([Wang et al. (2019)](https://arxiv.org/abs/1903.07293)) and our dataset is extracted from [DGL](https://www.dgl.ai/)'s [ACM.mat](https://data.dgl.ai/dataset/ACM.mat).
#
# The original ACM dataset has three node types and two edge (relation) types. For simplicity, we simplify the heterogeneous graph to one node type and two edge types (shown below). This means that in our heterogeneous graph, we have one node type (paper) and two message types (paper, author, paper) and (paper, subject, paper).
#
# <br/>
# <center>
# <img src="http://web.stanford.edu/class/cs224w/images/colab4/cs224w-acm.png"/>
# </center>

# %%
print("Device: {}".format(args['device']))

# Load the data
data = torch.load("acm.pkl")

# Message types
message_type_1 = ("paper", "author", "paper")
message_type_2 = ("paper", "subject", "paper")

# Dictionary of edge indices
edge_index = {}
edge_index[message_type_1] = data['pap']
edge_index[message_type_2] = data['psp']

# Dictionary of node features
node_feature = {}
node_feature["paper"] = data['feature']

# Dictionary of node labels
node_label = {}
node_label["paper"] = data['label']

# Load the train, validation and test indices
train_idx = {"paper": data['train_idx'].to(args['device'])}
val_idx = {"paper": data['val_idx'].to(args['device'])}
test_idx = {"paper": data['test_idx'].to(args['device'])}

# Construct a deepsnap tensor backend HeteroGraph
hetero_graph = HeteroGraph(
    node_feature=node_feature,
    node_label=node_label,
    edge_index=edge_index,
    directed=True
)

print(f"ACM heterogeneous graph: {hetero_graph.num_nodes()} nodes, {hetero_graph.num_edges()} edges")

# Node feature and node label to device
for key in hetero_graph.node_feature:
    hetero_graph.node_feature[key] = hetero_graph.node_feature[key].to(args['device'])
for key in hetero_graph.node_label:
    hetero_graph.node_label[key] = hetero_graph.node_label[key].to(args['device'])

# Edge_index to sparse tensor and to device
for key in hetero_graph.edge_index:
    edge_index = hetero_graph.edge_index[key]
    adj = SparseTensor(row=edge_index[0], col=edge_index[1], sparse_sizes=(hetero_graph.num_nodes('paper'), hetero_graph.num_nodes('paper')))
    hetero_graph.edge_index[key] = adj.t().to(args['device'])
print(hetero_graph.edge_index[message_type_1])
print(hetero_graph.edge_index[message_type_2])
# Out:
# Device: cpu
# ACM heterogeneous graph: {'paper': 3025} nodes, {('paper', 'author', 'paper'): 26256, ('paper', 'subject', 'paper'): 2207736} edges
# SparseTensor(row=tensor([   0,    0,    0,  ..., 3024, 3024, 3024]),
#              col=tensor([   8,   20,   51,  ..., 2948, 2983, 2991]),
#              size=(3025, 3025), nnz=26256, density=0.29%)
# SparseTensor(row=tensor([   0,    0,    0,  ..., 3024, 3024, 3024]),
#              col=tensor([  75,  434,  534,  ..., 3020, 3021, 3022]),
#              size=(3025, 3025), nnz=2207736, density=24.13%)

# %%
print(hetero_graph.node_label)
for message_type in hetero_graph.message_types:
      node_type_0 = message_type[0]
      node_type_2 = message_type[2]
      feat_dim_0 = hetero_graph.num_node_features(node_type_0)
      feat_dim_2 = hetero_graph.num_node_features(node_type_2)
      print(node_type_0, node_type_2, feat_dim_0, feat_dim_2)
# Out:
# {'paper': tensor([0, 0, 0,  ..., 2, 2, 2])}
# paper paper 1870 1870
# paper paper 1870 1870

# %% [markdown]
# ## Start Training!
#
# Now lets start training!

# %% [markdown]
# ## Training the Mean Aggregation

# %%
best_model = None
best_val = 0

model = HeteroGNN(hetero_graph, args, aggr="mean").to(args['device'])
optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'], weight_decay=args['weight_decay'])

for epoch in range(args['epochs']):
    loss = train(model, optimizer, hetero_graph, train_idx)
    accs, best_model, best_val = test(model, hetero_graph, [train_idx, val_idx, test_idx], best_model, best_val)
    print(
        f"Epoch {epoch + 1}: loss {round(loss, 5)}, "
        f"train micro {round(accs[0][0] * 100, 2)}%, train macro {round(accs[0][1] * 100, 2)}%, "
        f"valid micro {round(accs[1][0] * 100, 2)}%, valid macro {round(accs[1][1] * 100, 2)}%, "
        f"test micro {round(accs[2][0] * 100, 2)}%, test macro {round(accs[2][1] * 100, 2)}%"
    )
best_accs, _, _ = test(best_model, hetero_graph, [train_idx, val_idx, test_idx])
print(
    f"Best model: "
    f"train micro {round(best_accs[0][0] * 100, 2)}%, train macro {round(best_accs[0][1] * 100, 2)}%, "
    f"valid micro {round(best_accs[1][0] * 100, 2)}%, valid macro {round(best_accs[1][1] * 100, 2)}%, "
    f"test micro {round(best_accs[2][0] * 100, 2)}%, test macro {round(best_accs[2][1] * 100, 2)}%"
)
# Out:
# paper paper 1870 1870
# paper paper 1870 1870
# {('paper', 'author', 'paper'): HeteroGNNConv(
#   (lin_dst): Linear(in_features=64, out_features=64, bias=True)
#   (lin_src): Linear(in_features=64, out_features=64, bias=True)
#   (lin_update): Linear(in_features=128, out_features=64, bias=True)
# ), ('paper', 'subject', 'paper'): HeteroGNNConv(
#   (lin_dst): Linear(in_features=64, out_features=64, bias=True)
#   (lin_src): Linear(in_features=64, out_features=64, bias=True)
#   (lin_update): Linear(in_features=128, out_features=64, bias=True)
# )}
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# Epoch 1: loss 1.10256, train micro 33.33%, train macro 16.67%, valid micro 33.33%, valid macro 16.67%, test micro 35.81%, test macro 17.58%
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-52-704090ddff0d> in <module>()
#       6
#       7 for epoch in range(args['epochs']):
# ----> 8     loss = train(model, optimizer, hetero_graph, train_idx)
#       9     accs, best_model, best_val = test(model, hetero_graph, [train_idx, val_idx, test_idx], best_model, best_val)
#      10     print(
#
# <ipython-input-44-9a02af151ac7> in train(model, optimizer, hetero_graph, train_idx)
#       2     model.train()
#       3     optimizer.zero_grad()
# ----> 4     preds = model(hetero_graph.node_feature, hetero_graph.edge_index)
#       5
#       6     loss = None
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# <ipython-input-43-eb6601d0d7f2> in forward(self, node_feature, edge_index)
#      53         ## Note:
#      54         ## 1. `deepsnap.hetero_gnn.forward_op` can be helpful.
# ---> 55         x = self.convs1(x, edge_index)
#      56         x = forward_op(x, self.bns1)
#      57         x = forward_op(x, self.relus1)
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# <ipython-input-51-1e1f16ba7fab> in forward(self, node_features, edge_indices)
#      52                     node_feature_src,
#      53                     node_feature_dst,
# ---> 54                     edge_index,
#      55                 )
#      56             )
#
# /usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# <ipython-input-40-31f79538be24> in forward(self, node_feature_src, node_feature_dst, edge_index, size, res_n_id)
#      36                               node_feature_src=node_feature_src,
#      37                               node_feature_dst=node_feature_dst,
# ---> 38                               res_n_id=res_n_id)
#      39
#      40
#
# /usr/local/lib/python3.7/dist-packages/torch_geometric/nn/conv/message_passing.py in propagate(self, edge_index, size, **kwargs)
#     224             msg_aggr_kwargs = self.inspector.distribute(
#     225                 'message_and_aggregate', coll_dict)
# --> 226             out = self.message_and_aggregate(edge_index, **msg_aggr_kwargs)
#     227
#     228             update_kwargs = self.inspector.distribute('update', coll_dict)
#
# <ipython-input-40-31f79538be24> in message_and_aggregate(self, edge_index, node_feature_src)
#      56         adj_t = edge_index
#      57         x = node_feature_src
# ---> 58         return matmul(adj_t, x, reduce=self.aggr)
#      59
#      60
#
# /usr/local/lib/python3.7/dist-packages/torch_sparse/matmul.py in matmul(src, other, reduce)
#     114 def matmul(src, other, reduce="sum"):  # noqa: F811
#     115     if isinstance(other, torch.Tensor):
# --> 116         return spmm(src, other, reduce)
#     117     elif isinstance(other, SparseTensor):
#     118         return spspmm(src, other, reduce)
#
# /usr/local/lib/python3.7/dist-packages/torch_sparse/matmul.py in spmm(src, other, reduce)
#      66         return spmm_sum(src, other)
#      67     elif reduce == 'mean':
# ---> 68         return spmm_mean(src, other)
#      69     elif reduce == 'min':
#      70         return spmm_min(src, other)[0]
#
# /usr/local/lib/python3.7/dist-packages/torch_sparse/matmul.py in spmm_mean(src, other)
#      46
#      47     return torch.ops.torch_sparse.spmm_mean(row, rowptr, col, value, rowcount,
# ---> 48                                             colptr, csr2csc, other)
#      49
#      50
#
# KeyboardInterrupt:

# %% [markdown]
# ## Question 2.1: What is the maximum **micro** F1 score you could get for the best_model on test set when using the mean aggregation? (10 points)
#
# Submit your answers on Gradescope.

# %% [markdown]
# ## Question 2.2: What is the maximum **macro** F1 score you could get for the best_model on test set when using the mean aggregation? (10 points)
#
# Submit your answers on Gradescope.

# %% [markdown]
# ## Training the Attention Aggregation

# %%
best_model = None
best_val = 0

output_size = hetero_graph.num_node_labels('paper')
model = HeteroGNN(hetero_graph, args, aggr="attn").to(args['device'])
optimizer = torch.optim.Adam(model.parameters(), lr=args['lr'], weight_decay=args['weight_decay'])

for epoch in range(args['epochs']):
    loss = train(model, optimizer, hetero_graph, train_idx)
    accs, best_model, best_val = test(model, hetero_graph, [train_idx, val_idx, test_idx], best_model, best_val)
    print(
        f"Epoch {epoch + 1}: loss {round(loss, 5)}, "
        f"train micro {round(accs[0][0] * 100, 2)}%, train macro {round(accs[0][1] * 100, 2)}%, "
        f"valid micro {round(accs[1][0] * 100, 2)}%, valid macro {round(accs[1][1] * 100, 2)}%, "
        f"test micro {round(accs[2][0] * 100, 2)}%, test macro {round(accs[2][1] * 100, 2)}%"
    )
best_accs, _, _ = test(best_model, hetero_graph, [train_idx, val_idx,  test_idx])
print(
    f"Best model: "
    f"train micro {round(best_accs[0][0] * 100, 2)}%, train macro {round(best_accs[0][1] * 100, 2)}%, "
    f"valid micro {round(best_accs[1][0] * 100, 2)}%, valid macro {round(best_accs[1][1] * 100, 2)}%, "
    f"test micro {round(best_accs[2][0] * 100, 2)}%, test macro {round(best_accs[2][1] * 100, 2)}%"
)
# Out:
# paper paper 1870 1870
# paper paper 1870 1870
# {('paper', 'author', 'paper'): HeteroGNNConv(
#   (lin_dst): Linear(in_features=64, out_features=64, bias=True)
#   (lin_src): Linear(in_features=64, out_features=64, bias=True)
#   (lin_update): Linear(in_features=128, out_features=64, bias=True)
# ), ('paper', 'subject', 'paper'): HeteroGNNConv(
#   (lin_dst): Linear(in_features=64, out_features=64, bias=True)
#   (lin_src): Linear(in_features=64, out_features=64, bias=True)
#   (lin_update): Linear(in_features=128, out_features=64, bias=True)
# )}
# torch.Size([2])
# tensor([0.5014, 0.4986], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4996, 0.5004], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4992, 0.5008], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5006, 0.4994], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4992, 0.5008], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5006, 0.4994], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4992, 0.5008], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5006, 0.4994], grad_fn=<SoftmaxBackward>)
# Epoch 1: loss 1.09982, train micro 33.33%, train macro 16.67%, valid micro 33.33%, valid macro 16.67%, test micro 32.89%, test macro 16.5%
# torch.Size([2])
# tensor([0.4992, 0.5008], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4999, 0.5001], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4950, 0.5050], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5034, 0.4966], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4950, 0.5050], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5034, 0.4966], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4950, 0.5050], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5034, 0.4966], grad_fn=<SoftmaxBackward>)
# Epoch 2: loss 1.09187, train micro 50.83%, train macro 42.16%, valid micro 44.33%, valid macro 35.56%, test micro 35.76%, test macro 24.21%
# torch.Size([2])
# tensor([0.4950, 0.5050], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5002, 0.4998], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4903, 0.5097], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5068, 0.4932], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4903, 0.5097], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5068, 0.4932], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4903, 0.5097], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5068, 0.4932], grad_fn=<SoftmaxBackward>)
# Epoch 3: loss 1.06473, train micro 70.67%, train macro 66.48%, valid micro 64.0%, valid macro 58.8%, test micro 54.64%, test macro 47.08%
# torch.Size([2])
# tensor([0.4903, 0.5097], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5001, 0.4999], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4859, 0.5141], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5108, 0.4892], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4859, 0.5141], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5108, 0.4892], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4859, 0.5141], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5108, 0.4892], grad_fn=<SoftmaxBackward>)
# Epoch 4: loss 1.00995, train micro 68.5%, train macro 61.25%, valid micro 66.33%, valid macro 56.61%, test micro 63.11%, test macro 52.32%
# torch.Size([2])
# tensor([0.4859, 0.5141], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4999, 0.5001], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4822, 0.5178], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5153, 0.4847], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4822, 0.5178], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5153, 0.4847], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4822, 0.5178], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5153, 0.4847], grad_fn=<SoftmaxBackward>)
# Epoch 5: loss 0.91462, train micro 62.67%, train macro 54.85%, valid micro 60.33%, valid macro 49.6%, test micro 57.22%, test macro 46.11%
# torch.Size([2])
# tensor([0.4822, 0.5178], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4994, 0.5006], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4792, 0.5208], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5190, 0.4810], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4792, 0.5208], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5190, 0.4810], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4792, 0.5208], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5190, 0.4810], grad_fn=<SoftmaxBackward>)
# Epoch 6: loss 0.77357, train micro 59.33%, train macro 52.36%, valid micro 58.67%, valid macro 48.52%, test micro 54.35%, test macro 43.59%
# torch.Size([2])
# tensor([0.4792, 0.5208], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4983, 0.5017], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5202, 0.4798], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5202, 0.4798], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5202, 0.4798], grad_fn=<SoftmaxBackward>)
# Epoch 7: loss 0.60376, train micro 62.5%, train macro 57.08%, valid micro 61.0%, valid macro 52.16%, test micro 55.76%, test macro 45.1%
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4962, 0.5038], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4728, 0.5272], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5171, 0.4829], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4728, 0.5272], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5171, 0.4829], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4728, 0.5272], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5171, 0.4829], grad_fn=<SoftmaxBackward>)
# Epoch 8: loss 0.44549, train micro 68.67%, train macro 64.24%, valid micro 66.0%, valid macro 57.91%, test micro 59.2%, test macro 48.4%
# torch.Size([2])
# tensor([0.4728, 0.5272], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4932, 0.5068], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4686, 0.5314], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5098, 0.4902], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4686, 0.5314], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5098, 0.4902], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4686, 0.5314], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.5098, 0.4902], grad_fn=<SoftmaxBackward>)
# Epoch 9: loss 0.32634, train micro 76.17%, train macro 73.44%, valid micro 70.67%, valid macro 64.78%, test micro 62.64%, test macro 52.16%
# torch.Size([2])
# tensor([0.4686, 0.5314], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4894, 0.5106], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4646, 0.5354], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4995, 0.5005], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4646, 0.5354], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4995, 0.5005], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4646, 0.5354], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4995, 0.5005], grad_fn=<SoftmaxBackward>)
# Epoch 10: loss 0.24083, train micro 83.67%, train macro 82.44%, valid micro 76.0%, valid macro 72.21%, test micro 65.6%, test macro 56.57%
# torch.Size([2])
# tensor([0.4646, 0.5354], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4853, 0.5147], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4615, 0.5385], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4889, 0.5111], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4615, 0.5385], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4889, 0.5111], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4615, 0.5385], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4889, 0.5111], grad_fn=<SoftmaxBackward>)
# Epoch 11: loss 0.17753, train micro 90.33%, train macro 90.01%, valid micro 83.0%, valid macro 81.62%, test micro 68.47%, test macro 61.15%
# torch.Size([2])
# tensor([0.4615, 0.5385], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4818, 0.5182], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4595, 0.5405], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4808, 0.5192], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4595, 0.5405], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4808, 0.5192], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4595, 0.5405], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4808, 0.5192], grad_fn=<SoftmaxBackward>)
# Epoch 12: loss 0.13149, train micro 93.83%, train macro 93.72%, valid micro 89.0%, valid macro 88.62%, test micro 71.15%, test macro 65.69%
# torch.Size([2])
# tensor([0.4595, 0.5405], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4795, 0.5205], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4585, 0.5415], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4766, 0.5234], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4585, 0.5415], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4766, 0.5234], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4585, 0.5415], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4766, 0.5234], grad_fn=<SoftmaxBackward>)
# Epoch 13: loss 0.09955, train micro 97.0%, train macro 96.98%, valid micro 91.33%, valid macro 91.14%, test micro 74.64%, test macro 71.08%
# torch.Size([2])
# tensor([0.4585, 0.5415], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4786, 0.5214], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4580, 0.5420], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4580, 0.5420], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4580, 0.5420], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# Epoch 14: loss 0.07793, train micro 98.5%, train macro 98.5%, valid micro 92.67%, valid macro 92.54%, test micro 77.69%, test macro 75.4%
# torch.Size([2])
# tensor([0.4580, 0.5420], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4788, 0.5212], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4579, 0.5421], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4767, 0.5233], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4579, 0.5421], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4767, 0.5233], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4579, 0.5421], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4767, 0.5233], grad_fn=<SoftmaxBackward>)
# Epoch 15: loss 0.06274, train micro 98.83%, train macro 98.83%, valid micro 94.0%, valid macro 93.9%, test micro 80.05%, test macro 78.54%
# torch.Size([2])
# tensor([0.4579, 0.5421], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4798, 0.5202], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4580, 0.5420], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4788, 0.5212], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4580, 0.5420], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4788, 0.5212], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4580, 0.5420], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4788, 0.5212], grad_fn=<SoftmaxBackward>)
# Epoch 16: loss 0.05124, train micro 99.17%, train macro 99.17%, valid micro 95.67%, valid macro 95.62%, test micro 81.98%, test macro 80.96%
# torch.Size([2])
# tensor([0.4580, 0.5420], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4811, 0.5189], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4582, 0.5418], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4810, 0.5190], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4582, 0.5418], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4810, 0.5190], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4582, 0.5418], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4810, 0.5190], grad_fn=<SoftmaxBackward>)
# Epoch 17: loss 0.04213, train micro 99.67%, train macro 99.67%, valid micro 97.33%, valid macro 97.32%, test micro 84.19%, test macro 83.54%
# torch.Size([2])
# tensor([0.4582, 0.5418], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4825, 0.5175], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4587, 0.5413], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4831, 0.5169], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4587, 0.5413], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4831, 0.5169], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4587, 0.5413], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4831, 0.5169], grad_fn=<SoftmaxBackward>)
# Epoch 18: loss 0.03486, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 96.99%, test micro 84.94%, test macro 84.45%
# torch.Size([2])
# tensor([0.4587, 0.5413], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4839, 0.5161], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4593, 0.5407], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4847, 0.5153], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4593, 0.5407], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4847, 0.5153], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4593, 0.5407], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4847, 0.5153], grad_fn=<SoftmaxBackward>)
# Epoch 19: loss 0.02901, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 85.6%, test macro 85.2%
# torch.Size([2])
# tensor([0.4593, 0.5407], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4850, 0.5150], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4601, 0.5399], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4858, 0.5142], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4601, 0.5399], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4858, 0.5142], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4601, 0.5399], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4858, 0.5142], grad_fn=<SoftmaxBackward>)
# Epoch 20: loss 0.0242, train micro 100.0%, train macro 100.0%, valid micro 97.67%, valid macro 97.66%, test micro 86.26%, test macro 85.97%
# torch.Size([2])
# tensor([0.4601, 0.5399], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4858, 0.5142], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4610, 0.5390], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4867, 0.5133], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4610, 0.5390], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4867, 0.5133], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4610, 0.5390], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4867, 0.5133], grad_fn=<SoftmaxBackward>)
# Epoch 21: loss 0.0202, train micro 100.0%, train macro 100.0%, valid micro 97.67%, valid macro 97.66%, test micro 86.26%, test macro 85.98%
# torch.Size([2])
# tensor([0.4610, 0.5390], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4862, 0.5138], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4621, 0.5379], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4872, 0.5128], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4621, 0.5379], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4872, 0.5128], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4621, 0.5379], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4872, 0.5128], grad_fn=<SoftmaxBackward>)
# Epoch 22: loss 0.0169, train micro 100.0%, train macro 100.0%, valid micro 98.0%, valid macro 98.0%, test micro 86.54%, test macro 86.32%
# torch.Size([2])
# tensor([0.4621, 0.5379], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4864, 0.5136], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4632, 0.5368], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4875, 0.5125], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4632, 0.5368], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4875, 0.5125], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4632, 0.5368], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4875, 0.5125], grad_fn=<SoftmaxBackward>)
# Epoch 23: loss 0.01413, train micro 100.0%, train macro 100.0%, valid micro 97.67%, valid macro 97.67%, test micro 86.59%, test macro 86.38%
# torch.Size([2])
# tensor([0.4632, 0.5368], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4864, 0.5136], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4643, 0.5357], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4876, 0.5124], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4643, 0.5357], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4876, 0.5124], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4643, 0.5357], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4876, 0.5124], grad_fn=<SoftmaxBackward>)
# Epoch 24: loss 0.01169, train micro 100.0%, train macro 100.0%, valid micro 97.33%, valid macro 97.33%, test micro 86.64%, test macro 86.42%
# torch.Size([2])
# tensor([0.4643, 0.5357], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4862, 0.5138], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4654, 0.5346], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4877, 0.5123], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4654, 0.5346], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4877, 0.5123], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4654, 0.5346], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4877, 0.5123], grad_fn=<SoftmaxBackward>)
# Epoch 25: loss 0.00961, train micro 100.0%, train macro 100.0%, valid micro 97.0%, valid macro 97.0%, test micro 86.73%, test macro 86.52%
# torch.Size([2])
# tensor([0.4654, 0.5346], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4859, 0.5141], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4665, 0.5335], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4875, 0.5125], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4665, 0.5335], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4875, 0.5125], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4665, 0.5335], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4875, 0.5125], grad_fn=<SoftmaxBackward>)
# Epoch 26: loss 0.00792, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.34%, test micro 86.59%, test macro 86.38%
# torch.Size([2])
# tensor([0.4665, 0.5335], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4855, 0.5145], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4676, 0.5324], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4873, 0.5127], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4676, 0.5324], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4873, 0.5127], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4676, 0.5324], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4873, 0.5127], grad_fn=<SoftmaxBackward>)
# Epoch 27: loss 0.00653, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.34%, test micro 86.49%, test macro 86.28%
# torch.Size([2])
# tensor([0.4676, 0.5324], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4850, 0.5150], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4685, 0.5315], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4871, 0.5129], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4685, 0.5315], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4871, 0.5129], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4685, 0.5315], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4871, 0.5129], grad_fn=<SoftmaxBackward>)
# Epoch 28: loss 0.00542, train micro 100.0%, train macro 100.0%, valid micro 96.0%, valid macro 96.01%, test micro 86.21%, test macro 86.01%
# torch.Size([2])
# tensor([0.4685, 0.5315], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4845, 0.5155], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4694, 0.5306], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4867, 0.5133], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4694, 0.5306], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4867, 0.5133], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4694, 0.5306], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4867, 0.5133], grad_fn=<SoftmaxBackward>)
# Epoch 29: loss 0.00454, train micro 100.0%, train macro 100.0%, valid micro 95.67%, valid macro 95.68%, test micro 86.16%, test macro 85.96%
# torch.Size([2])
# tensor([0.4694, 0.5306], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4840, 0.5160], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4702, 0.5298], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4863, 0.5137], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4702, 0.5298], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4863, 0.5137], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4702, 0.5298], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4863, 0.5137], grad_fn=<SoftmaxBackward>)
# Epoch 30: loss 0.00386, train micro 100.0%, train macro 100.0%, valid micro 95.67%, valid macro 95.68%, test micro 85.98%, test macro 85.77%
# torch.Size([2])
# tensor([0.4702, 0.5298], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4835, 0.5165], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4709, 0.5291], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4859, 0.5141], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4709, 0.5291], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4859, 0.5141], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4709, 0.5291], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4859, 0.5141], grad_fn=<SoftmaxBackward>)
# Epoch 31: loss 0.00333, train micro 100.0%, train macro 100.0%, valid micro 95.67%, valid macro 95.68%, test micro 85.84%, test macro 85.63%
# torch.Size([2])
# tensor([0.4709, 0.5291], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4829, 0.5171], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4715, 0.5285], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4855, 0.5145], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4715, 0.5285], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4855, 0.5145], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4715, 0.5285], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4855, 0.5145], grad_fn=<SoftmaxBackward>)
# Epoch 32: loss 0.0029, train micro 100.0%, train macro 100.0%, valid micro 95.67%, valid macro 95.68%, test micro 85.93%, test macro 85.74%
# torch.Size([2])
# tensor([0.4715, 0.5285], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4824, 0.5176], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4721, 0.5279], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4850, 0.5150], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4721, 0.5279], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4850, 0.5150], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4721, 0.5279], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4850, 0.5150], grad_fn=<SoftmaxBackward>)
# Epoch 33: loss 0.00256, train micro 100.0%, train macro 100.0%, valid micro 95.67%, valid macro 95.68%, test micro 85.79%, test macro 85.6%
# torch.Size([2])
# tensor([0.4721, 0.5279], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4820, 0.5180], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4725, 0.5275], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4845, 0.5155], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4725, 0.5275], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4845, 0.5155], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4725, 0.5275], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4845, 0.5155], grad_fn=<SoftmaxBackward>)
# Epoch 34: loss 0.00227, train micro 100.0%, train macro 100.0%, valid micro 95.33%, valid macro 95.35%, test micro 85.74%, test macro 85.56%
# torch.Size([2])
# tensor([0.4725, 0.5275], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4815, 0.5185], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4730, 0.5270], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4841, 0.5159], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4730, 0.5270], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4841, 0.5159], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4730, 0.5270], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4841, 0.5159], grad_fn=<SoftmaxBackward>)
# Epoch 35: loss 0.00204, train micro 100.0%, train macro 100.0%, valid micro 95.33%, valid macro 95.35%, test micro 85.65%, test macro 85.47%
# torch.Size([2])
# tensor([0.4730, 0.5270], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4811, 0.5189], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4734, 0.5266], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4836, 0.5164], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4734, 0.5266], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4836, 0.5164], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4734, 0.5266], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4836, 0.5164], grad_fn=<SoftmaxBackward>)
# Epoch 36: loss 0.00184, train micro 100.0%, train macro 100.0%, valid micro 95.33%, valid macro 95.35%, test micro 85.41%, test macro 85.23%
# torch.Size([2])
# tensor([0.4734, 0.5266], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4807, 0.5193], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4737, 0.5263], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4832, 0.5168], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4737, 0.5263], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4832, 0.5168], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4737, 0.5263], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4832, 0.5168], grad_fn=<SoftmaxBackward>)
# Epoch 37: loss 0.00168, train micro 100.0%, train macro 100.0%, valid micro 95.33%, valid macro 95.35%, test micro 85.41%, test macro 85.23%
# torch.Size([2])
# tensor([0.4737, 0.5263], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4803, 0.5197], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4740, 0.5260], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4828, 0.5172], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4740, 0.5260], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4828, 0.5172], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4740, 0.5260], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4828, 0.5172], grad_fn=<SoftmaxBackward>)
# Epoch 38: loss 0.00154, train micro 100.0%, train macro 100.0%, valid micro 95.67%, valid macro 95.68%, test micro 85.41%, test macro 85.24%
# torch.Size([2])
# tensor([0.4740, 0.5260], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4799, 0.5201], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4742, 0.5258], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4823, 0.5177], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4742, 0.5258], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4823, 0.5177], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4742, 0.5258], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4823, 0.5177], grad_fn=<SoftmaxBackward>)
# Epoch 39: loss 0.00142, train micro 100.0%, train macro 100.0%, valid micro 95.67%, valid macro 95.68%, test micro 85.36%, test macro 85.19%
# torch.Size([2])
# tensor([0.4742, 0.5258], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4796, 0.5204], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4745, 0.5255], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4819, 0.5181], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4745, 0.5255], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4819, 0.5181], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4745, 0.5255], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4819, 0.5181], grad_fn=<SoftmaxBackward>)
# Epoch 40: loss 0.00131, train micro 100.0%, train macro 100.0%, valid micro 95.67%, valid macro 95.68%, test micro 85.36%, test macro 85.19%
# torch.Size([2])
# tensor([0.4745, 0.5255], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4793, 0.5207], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4747, 0.5253], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4816, 0.5184], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4747, 0.5253], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4816, 0.5184], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4747, 0.5253], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4816, 0.5184], grad_fn=<SoftmaxBackward>)
# Epoch 41: loss 0.00122, train micro 100.0%, train macro 100.0%, valid micro 95.67%, valid macro 95.68%, test micro 85.41%, test macro 85.24%
# torch.Size([2])
# tensor([0.4747, 0.5253], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4791, 0.5209], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4748, 0.5252], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4812, 0.5188], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4748, 0.5252], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4812, 0.5188], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4748, 0.5252], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4812, 0.5188], grad_fn=<SoftmaxBackward>)
# Epoch 42: loss 0.00114, train micro 100.0%, train macro 100.0%, valid micro 95.67%, valid macro 95.68%, test micro 85.46%, test macro 85.3%
# torch.Size([2])
# tensor([0.4748, 0.5252], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4789, 0.5211], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4750, 0.5250], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4809, 0.5191], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4750, 0.5250], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4809, 0.5191], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4750, 0.5250], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4809, 0.5191], grad_fn=<SoftmaxBackward>)
# Epoch 43: loss 0.00107, train micro 100.0%, train macro 100.0%, valid micro 95.67%, valid macro 95.68%, test micro 85.6%, test macro 85.45%
# torch.Size([2])
# tensor([0.4750, 0.5250], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4786, 0.5214], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4751, 0.5249], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4805, 0.5195], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4751, 0.5249], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4805, 0.5195], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4751, 0.5249], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4805, 0.5195], grad_fn=<SoftmaxBackward>)
# Epoch 44: loss 0.00101, train micro 100.0%, train macro 100.0%, valid micro 95.67%, valid macro 95.68%, test micro 85.55%, test macro 85.41%
# torch.Size([2])
# tensor([0.4751, 0.5249], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4785, 0.5215], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4752, 0.5248], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4802, 0.5198], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4752, 0.5248], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4802, 0.5198], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4752, 0.5248], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4802, 0.5198], grad_fn=<SoftmaxBackward>)
# Epoch 45: loss 0.00096, train micro 100.0%, train macro 100.0%, valid micro 95.67%, valid macro 95.68%, test micro 85.6%, test macro 85.46%
# torch.Size([2])
# tensor([0.4752, 0.5248], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4783, 0.5217], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4753, 0.5247], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4799, 0.5201], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4753, 0.5247], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4799, 0.5201], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4753, 0.5247], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4799, 0.5201], grad_fn=<SoftmaxBackward>)
# Epoch 46: loss 0.00091, train micro 100.0%, train macro 100.0%, valid micro 96.0%, valid macro 96.01%, test micro 85.65%, test macro 85.52%
# torch.Size([2])
# tensor([0.4753, 0.5247], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4782, 0.5218], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4754, 0.5246], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4797, 0.5203], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4754, 0.5246], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4797, 0.5203], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4754, 0.5246], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4797, 0.5203], grad_fn=<SoftmaxBackward>)
# Epoch 47: loss 0.00086, train micro 100.0%, train macro 100.0%, valid micro 96.0%, valid macro 96.01%, test micro 85.69%, test macro 85.56%
# torch.Size([2])
# tensor([0.4754, 0.5246], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4780, 0.5220], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4755, 0.5245], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4794, 0.5206], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4755, 0.5245], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4794, 0.5206], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4755, 0.5245], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4794, 0.5206], grad_fn=<SoftmaxBackward>)
# Epoch 48: loss 0.00082, train micro 100.0%, train macro 100.0%, valid micro 96.0%, valid macro 96.01%, test micro 85.74%, test macro 85.62%
# torch.Size([2])
# tensor([0.4755, 0.5245], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4779, 0.5221], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4792, 0.5208], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4792, 0.5208], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4792, 0.5208], grad_fn=<SoftmaxBackward>)
# Epoch 49: loss 0.00079, train micro 100.0%, train macro 100.0%, valid micro 96.0%, valid macro 96.01%, test micro 85.65%, test macro 85.54%
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4778, 0.5222], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4789, 0.5211], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4789, 0.5211], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4789, 0.5211], grad_fn=<SoftmaxBackward>)
# Epoch 50: loss 0.00076, train micro 100.0%, train macro 100.0%, valid micro 96.0%, valid macro 96.01%, test micro 85.74%, test macro 85.64%
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4777, 0.5223], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4757, 0.5243], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4787, 0.5213], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4757, 0.5243], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4787, 0.5213], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4757, 0.5243], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4787, 0.5213], grad_fn=<SoftmaxBackward>)
# Epoch 51: loss 0.00073, train micro 100.0%, train macro 100.0%, valid micro 96.0%, valid macro 96.01%, test micro 85.65%, test macro 85.55%
# torch.Size([2])
# tensor([0.4757, 0.5243], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4776, 0.5224], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4757, 0.5243], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4785, 0.5215], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4757, 0.5243], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4785, 0.5215], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4757, 0.5243], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4785, 0.5215], grad_fn=<SoftmaxBackward>)
# Epoch 52: loss 0.0007, train micro 100.0%, train macro 100.0%, valid micro 96.0%, valid macro 96.01%, test micro 85.69%, test macro 85.6%
# torch.Size([2])
# tensor([0.4757, 0.5243], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4775, 0.5225], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4758, 0.5242], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4783, 0.5217], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4758, 0.5242], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4783, 0.5217], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4758, 0.5242], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4783, 0.5217], grad_fn=<SoftmaxBackward>)
# Epoch 53: loss 0.00067, train micro 100.0%, train macro 100.0%, valid micro 96.0%, valid macro 96.01%, test micro 85.6%, test macro 85.52%
# torch.Size([2])
# tensor([0.4758, 0.5242], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4774, 0.5226], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4758, 0.5242], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4781, 0.5219], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4758, 0.5242], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4781, 0.5219], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4758, 0.5242], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4781, 0.5219], grad_fn=<SoftmaxBackward>)
# Epoch 54: loss 0.00065, train micro 100.0%, train macro 100.0%, valid micro 96.0%, valid macro 96.01%, test micro 85.51%, test macro 85.42%
# torch.Size([2])
# tensor([0.4758, 0.5242], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4774, 0.5226], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4758, 0.5242], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4779, 0.5221], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4758, 0.5242], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4779, 0.5221], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4758, 0.5242], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4779, 0.5221], grad_fn=<SoftmaxBackward>)
# Epoch 55: loss 0.00063, train micro 100.0%, train macro 100.0%, valid micro 96.0%, valid macro 96.01%, test micro 85.51%, test macro 85.42%
# torch.Size([2])
# tensor([0.4758, 0.5242], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4773, 0.5227], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4759, 0.5241], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4778, 0.5222], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4759, 0.5241], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4778, 0.5222], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4759, 0.5241], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4778, 0.5222], grad_fn=<SoftmaxBackward>)
# Epoch 56: loss 0.00061, train micro 100.0%, train macro 100.0%, valid micro 96.0%, valid macro 96.01%, test micro 85.32%, test macro 85.25%
# torch.Size([2])
# tensor([0.4759, 0.5241], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4773, 0.5227], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4759, 0.5241], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4776, 0.5224], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4759, 0.5241], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4776, 0.5224], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4759, 0.5241], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4776, 0.5224], grad_fn=<SoftmaxBackward>)
# Epoch 57: loss 0.0006, train micro 100.0%, train macro 100.0%, valid micro 96.0%, valid macro 96.01%, test micro 85.32%, test macro 85.25%
# torch.Size([2])
# tensor([0.4759, 0.5241], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4772, 0.5228], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4759, 0.5241], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4775, 0.5225], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4759, 0.5241], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4775, 0.5225], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4759, 0.5241], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4775, 0.5225], grad_fn=<SoftmaxBackward>)
# Epoch 58: loss 0.00058, train micro 100.0%, train macro 100.0%, valid micro 96.0%, valid macro 96.01%, test micro 85.22%, test macro 85.16%
# torch.Size([2])
# tensor([0.4759, 0.5241], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4772, 0.5228], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4759, 0.5241], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4773, 0.5227], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4759, 0.5241], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4773, 0.5227], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4759, 0.5241], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4773, 0.5227], grad_fn=<SoftmaxBackward>)
# Epoch 59: loss 0.00056, train micro 100.0%, train macro 100.0%, valid micro 96.0%, valid macro 96.01%, test micro 85.13%, test macro 85.07%
# torch.Size([2])
# tensor([0.4759, 0.5241], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4771, 0.5229], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4760, 0.5240], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4772, 0.5228], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4760, 0.5240], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4772, 0.5228], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4760, 0.5240], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4772, 0.5228], grad_fn=<SoftmaxBackward>)
# Epoch 60: loss 0.00055, train micro 100.0%, train macro 100.0%, valid micro 96.0%, valid macro 96.01%, test micro 85.18%, test macro 85.13%
# torch.Size([2])
# tensor([0.4760, 0.5240], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4771, 0.5229], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4760, 0.5240], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4771, 0.5229], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4760, 0.5240], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4771, 0.5229], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4760, 0.5240], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4771, 0.5229], grad_fn=<SoftmaxBackward>)
# Epoch 61: loss 0.00054, train micro 100.0%, train macro 100.0%, valid micro 96.0%, valid macro 96.01%, test micro 85.27%, test macro 85.23%
# torch.Size([2])
# tensor([0.4760, 0.5240], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4770, 0.5230], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4760, 0.5240], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4770, 0.5230], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4760, 0.5240], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4770, 0.5230], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4760, 0.5240], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4770, 0.5230], grad_fn=<SoftmaxBackward>)
# Epoch 62: loss 0.00052, train micro 100.0%, train macro 100.0%, valid micro 96.0%, valid macro 96.01%, test micro 85.32%, test macro 85.28%
# torch.Size([2])
# tensor([0.4760, 0.5240], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4770, 0.5230], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4760, 0.5240], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4769, 0.5231], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4760, 0.5240], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4769, 0.5231], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4760, 0.5240], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4769, 0.5231], grad_fn=<SoftmaxBackward>)
# Epoch 63: loss 0.00051, train micro 100.0%, train macro 100.0%, valid micro 96.0%, valid macro 96.01%, test micro 85.36%, test macro 85.33%
# torch.Size([2])
# tensor([0.4760, 0.5240], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4770, 0.5230], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4760, 0.5240], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4768, 0.5232], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4760, 0.5240], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4768, 0.5232], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4760, 0.5240], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4768, 0.5232], grad_fn=<SoftmaxBackward>)
# ...
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4758, 0.5242], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4758, 0.5242], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4758, 0.5242], grad_fn=<SoftmaxBackward>)
# Epoch 80: loss 0.00039, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.36%, test micro 84.66%, test macro 84.66%
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4766, 0.5234], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4758, 0.5242], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4758, 0.5242], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4758, 0.5242], grad_fn=<SoftmaxBackward>)
# Epoch 81: loss 0.00038, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.36%, test micro 84.61%, test macro 84.62%
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4766, 0.5234], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4758, 0.5242], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4758, 0.5242], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4758, 0.5242], grad_fn=<SoftmaxBackward>)
# Epoch 82: loss 0.00038, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.36%, test micro 84.56%, test macro 84.57%
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4765, 0.5235], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4758, 0.5242], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4758, 0.5242], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4758, 0.5242], grad_fn=<SoftmaxBackward>)
# Epoch 83: loss 0.00037, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.36%, test micro 84.61%, test macro 84.62%
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4765, 0.5235], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4757, 0.5243], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4757, 0.5243], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4757, 0.5243], grad_fn=<SoftmaxBackward>)
# Epoch 84: loss 0.00037, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.36%, test micro 84.61%, test macro 84.62%
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4765, 0.5235], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4757, 0.5243], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4757, 0.5243], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4757, 0.5243], grad_fn=<SoftmaxBackward>)
# Epoch 85: loss 0.00036, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.36%, test micro 84.61%, test macro 84.62%
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4765, 0.5235], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4757, 0.5243], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4757, 0.5243], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4757, 0.5243], grad_fn=<SoftmaxBackward>)
# Epoch 86: loss 0.00036, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.36%, test micro 84.61%, test macro 84.62%
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4765, 0.5235], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4757, 0.5243], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4757, 0.5243], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4757, 0.5243], grad_fn=<SoftmaxBackward>)
# Epoch 87: loss 0.00036, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.36%, test micro 84.56%, test macro 84.58%
# torch.Size([2])
# tensor([0.4763, 0.5237], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4765, 0.5235], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4757, 0.5243], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4757, 0.5243], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4757, 0.5243], grad_fn=<SoftmaxBackward>)
# Epoch 88: loss 0.00035, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.36%, test micro 84.56%, test macro 84.58%
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4765, 0.5235], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# Epoch 89: loss 0.00035, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.36%, test micro 84.61%, test macro 84.62%
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4765, 0.5235], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# Epoch 90: loss 0.00034, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.36%, test micro 84.61%, test macro 84.62%
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4765, 0.5235], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# Epoch 91: loss 0.00034, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.36%, test micro 84.56%, test macro 84.58%
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# Epoch 92: loss 0.00034, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.36%, test micro 84.52%, test macro 84.53%
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# Epoch 93: loss 0.00033, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.36%, test micro 84.47%, test macro 84.49%
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# Epoch 94: loss 0.00033, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.36%, test micro 84.52%, test macro 84.54%
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# Epoch 95: loss 0.00033, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.36%, test micro 84.52%, test macro 84.54%
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4756, 0.5244], grad_fn=<SoftmaxBackward>)
# Epoch 96: loss 0.00032, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.36%, test micro 84.47%, test macro 84.49%
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4755, 0.5245], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4755, 0.5245], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4755, 0.5245], grad_fn=<SoftmaxBackward>)
# Epoch 97: loss 0.00032, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.36%, test micro 84.52%, test macro 84.54%
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4755, 0.5245], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4755, 0.5245], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4755, 0.5245], grad_fn=<SoftmaxBackward>)
# Epoch 98: loss 0.00032, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.36%, test micro 84.52%, test macro 84.54%
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4755, 0.5245], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4755, 0.5245], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4755, 0.5245], grad_fn=<SoftmaxBackward>)
# Epoch 99: loss 0.00031, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.36%, test micro 84.52%, test macro 84.54%
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([3025, 3]) torch.Size([600]) torch.Size([3025])
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4755, 0.5245], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4755, 0.5245], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4764, 0.5236], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4755, 0.5245], grad_fn=<SoftmaxBackward>)
# Epoch 100: loss 0.00031, train micro 100.0%, train macro 100.0%, valid micro 96.33%, valid macro 96.36%, test micro 84.56%, test macro 84.59%
# torch.Size([2])
# tensor([0.4621, 0.5379], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4872, 0.5128], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4621, 0.5379], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4872, 0.5128], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4621, 0.5379], grad_fn=<SoftmaxBackward>)
# torch.Size([2])
# tensor([0.4872, 0.5128], grad_fn=<SoftmaxBackward>)
# Best model: train micro 100.0%, train macro 100.0%, valid micro 98.0%, valid macro 98.0%, test micro 86.54%, test macro 86.32%

# %% [markdown]
# ## Question 2.3: What is the maximum **micro** F1 score you could get for the best_model on test set when using the attention aggregation? (4 points)
#
# Submit your answers on Gradescope.

# %% [markdown]
# ## Question 2.4: What is the maximum **macro** F1 score you could get for the best_model on test set when using the attention aggregation? (4 points)
#
# Submit your answers on Gradescope.

# %% [markdown]
# ## Attention for each Message Type
#
# Through message type level attention we can learn that which message type is more important to which layer.
#
# Here we will print out and show that each layer pay how much attention on each message type.

# %%
if model.convs1.alpha is not None and model.convs2.alpha is not None:
    for idx, message_type in model.convs1.mapping.items():
        print(f"Layer 1 has attention {model.convs1.alpha[idx]} on message type {message_type}")
    for idx, message_type in model.convs2.mapping.items():
        print(f"Layer 2 has attention {model.convs2.alpha[idx]} on message type {message_type}")

# %% [markdown]
# # Submission
#
# In order to get credit, you must go submit your answers on Gradescope.
#
# Also, you need to submit the `ipynb` file of Colab 4, by clicking `File` and `Download .ipynb`. Please make sure that your output of each cell is available in your `ipynb` file.
